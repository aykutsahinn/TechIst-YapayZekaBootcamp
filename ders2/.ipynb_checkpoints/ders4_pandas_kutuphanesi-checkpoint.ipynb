# %% [markdown]
# ## Pandas Kütüphanesi

# %% [markdown]
# Temel veri işleme kütüphanesidir
# Veri yükleme işlemleri
# Veri işleme ve manipülasyon işlemleri
# Veri analizi
# Veri dönüşümü ve modelleme
# Veri görselleştirme
# Raporlama

# %% [markdown]
# Anaconda kullanıyorsanız Pandas kütüphanesi yüklenmiş olarak gelir
# 'import pandas as pd' içe aktarılır
# Anaconda kullanmıyorsanız veya kurulu değilse altta ki komutla kurabilirsiniz

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install jupyter
# Out:
# Collecting jupyter
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl.metadata (995 bytes)
# Collecting notebook (from jupyter)
#   Downloading notebook-7.2.0-py3-none-any.whl.metadata (10 kB)
# Collecting qtconsole (from jupyter)
#   Downloading qtconsole-5.5.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting jupyter-console (from jupyter)
#   Downloading jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: nbconvert in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jupyter) (7.16.4)
# Requirement already satisfied: ipykernel in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jupyter) (6.29.4)
# Collecting ipywidgets (from jupyter)
#   Downloading ipywidgets-8.1.3-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: comm>=0.1.1 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter) (1.8.1)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter) (8.25.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter) (8.6.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: packaging in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter) (24.0)
# Requirement already satisfied: psutil in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter) (5.9.8)
# Requirement already satisfied: pyzmq>=24 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter) (26.0.3)
# Requirement already satisfied: tornado>=6.1 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter) (6.4)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter) (5.14.3)
# Collecting widgetsnbextension~=4.0.11 (from ipywidgets->jupyter)
#   Downloading widgetsnbextension-4.0.11-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.11 (from ipywidgets->jupyter)
#   Downloading jupyterlab_widgets-3.0.11-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jupyter-console->jupyter) (3.0.46)
# Requirement already satisfied: pygments in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jupyter-console->jupyter) (2.18.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter) (6.1.0)
# Requirement already satisfied: defusedxml in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter) (3.1.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter) (2.1.5)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter) (0.10.0)
# Requirement already satisfied: nbformat>=5.7 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: tinycss2 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter) (1.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from notebook->jupyter) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from notebook->jupyter) (2.27.2)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from notebook->jupyter) (4.2.1)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from notebook->jupyter) (0.2.4)
# Collecting qtpy>=2.4.0 (from qtconsole->jupyter)
#   Downloading QtPy-2.4.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: six>=1.9.0 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: decorator in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.1)
# Requirement already satisfied: stack-data in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.3)
# Requirement already satisfied: colorama in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.2.2)
# Requirement already satisfied: pywin32>=300 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (306)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (4.4.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.20.0)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (2.0.13)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter) (0.27.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter) (2.2.5)
# Requirement already satisfied: babel>=2.10 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter) (2.15.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter) (4.22.0)
# Requirement already satisfied: requests>=2.31 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter) (2.32.3)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.19.1)
# Requirement already satisfied: wcwidth in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.5)
# Requirement already satisfied: idna>=2.8 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter) (21.2.0)
# Requirement already satisfied: certifi in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (0.18.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (2.2.1)
# Requirement already satisfied: executing>=1.2.0 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: fqdn in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.4)
# Requirement already satisfied: uri-template in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\aykut\appdata\local\programs\python\python312\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.9.0.20240316)
# Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Downloading ipywidgets-8.1.3-py3-none-any.whl (139 kB)
#    ---------------------------------------- 0.0/139.4 kB ? eta -:--:--
#    -------- ------------------------------ 30.7/139.4 kB 660.6 kB/s eta 0:00:01
#    -------------------- ------------------ 71.7/139.4 kB 787.7 kB/s eta 0:00:01
#    --------------------------------- ---- 122.9/139.4 kB 901.1 kB/s eta 0:00:01
#    ------------------------------------ - 133.1/139.4 kB 983.0 kB/s eta 0:00:01
#    ------------------------------------ - 133.1/139.4 kB 983.0 kB/s eta 0:00:01
#    ------------------------------------ - 133.1/139.4 kB 983.0 kB/s eta 0:00:01
#    -------------------------------------- 139.4/139.4 kB 487.4 kB/s eta 0:00:00
# Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Downloading notebook-7.2.0-py3-none-any.whl (5.0 MB)
#    ---------------------------------------- 0.0/5.0 MB ? eta -:--:--
#     --------------------------------------- 0.1/5.0 MB 3.6 MB/s eta 0:00:02
#    -- ------------------------------------- 0.3/5.0 MB 2.6 MB/s eta 0:00:02
#    -- ------------------------------------- 0.3/5.0 MB 2.8 MB/s eta 0:00:02
#    -- ------------------------------------- 0.3/5.0 MB 2.8 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.6/5.0 MB 2.5 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.7/5.0 MB 2.9 MB/s eta 0:00:02
#    ------- -------------------------------- 0.9/5.0 MB 2.7 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.4/5.0 MB 3.6 MB/s eta 0:00:02
#    ------------ --------------------------- 1.5/5.0 MB 3.8 MB/s eta 0:00:01
#    ------------- -------------------------- 1.7/5.0 MB 3.8 MB/s eta 0:00:01
#    --------------- ------------------------ 1.9/5.0 MB 3.8 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.1/5.0 MB 3.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.2/5.0 MB 3.7 MB/s eta 0:00:01
#    ------------------- -------------------- 2.4/5.0 MB 3.8 MB/s eta 0:00:01
#    -------------------- ------------------- 2.6/5.0 MB 3.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 2.8/5.0 MB 3.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.0/5.0 MB 3.7 MB/s eta 0:00:01
#    ------------------------- -------------- 3.2/5.0 MB 3.7 MB/s eta 0:00:01
#    -------------------------- ------------- 3.4/5.0 MB 3.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 3.5/5.0 MB 3.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.7/5.0 MB 3.8 MB/s eta 0:00:01
#    ------------------------------- -------- 3.9/5.0 MB 3.8 MB/s eta 0:00:01
#    -------------------------------- ------- 4.1/5.0 MB 3.8 MB/s eta 0:00:01
#    --------------------------------- ------ 4.3/5.0 MB 3.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 4.5/5.0 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------- -- 4.7/5.0 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 4.8/5.0 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  5.0/5.0 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  5.0/5.0 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  5.0/5.0 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  5.0/5.0 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  5.0/5.0 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 5.0/5.0 MB 3.3 MB/s eta 0:00:00
# Downloading qtconsole-5.5.2-py3-none-any.whl (123 kB)
#    ---------------------------------------- 0.0/123.4 kB ? eta -:--:--
#    ---------------------------------------  122.9/123.4 kB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  122.9/123.4 kB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 123.4/123.4 kB 1.0 MB/s eta 0:00:00
# Downloading jupyterlab_widgets-3.0.11-py3-none-any.whl (214 kB)
#    ---------------------------------------- 0.0/214.4 kB ? eta -:--:--
#    -------------------------------- ------- 174.1/214.4 kB 5.1 MB/s eta 0:00:01
#    -------------------------------------- - 204.8/214.4 kB 6.1 MB/s eta 0:00:01
#    -------------------------------------- - 204.8/214.4 kB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 214.4/214.4 kB 1.2 MB/s eta 0:00:00
# Downloading QtPy-2.4.1-py3-none-any.whl (93 kB)
#    ---------------------------------------- 0.0/93.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/93.5 kB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  92.2/93.5 kB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  92.2/93.5 kB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  92.2/93.5 kB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  92.2/93.5 kB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  92.2/93.5 kB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  92.2/93.5 kB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  92.2/93.5 kB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  92.2/93.5 kB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  92.2/93.5 kB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  92.2/93.5 kB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  92.2/93.5 kB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 93.5/93.5 kB 148.1 kB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.11-py3-none-any.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.2/2.3 MB 3.5 MB/s eta 0:00:01
#    ------ --------------------------------- 0.4/2.3 MB 3.9 MB/s eta 0:00:01
#    --------- ------------------------------ 0.6/2.3 MB 3.9 MB/s eta 0:00:01
#    ------------- -------------------------- 0.8/2.3 MB 4.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.0/2.3 MB 4.1 MB/s eta 0:00:01
#    ------------------- -------------------- 1.1/2.3 MB 4.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.3/2.3 MB 4.1 MB/s eta 0:00:01
#    -------------------------- ------------- 1.5/2.3 MB 4.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.7/2.3 MB 4.1 MB/s eta 0:00:01
#    -------------------------------- ------- 1.9/2.3 MB 4.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.1/2.3 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------  2.3/2.3 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------  2.3/2.3 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  2.3/2.3 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  2.3/2.3 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  2.3/2.3 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  2.3/2.3 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  2.3/2.3 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 2.8 MB/s eta 0:00:00
# Installing collected packages: widgetsnbextension, qtpy, jupyterlab-widgets, ipywidgets, qtconsole, jupyter-console, notebook, jupyter
# Successfully installed ipywidgets-8.1.3 jupyter-1.0.0 jupyter-console-6.6.3 jupyterlab-widgets-3.0.11 notebook-7.2.0 qtconsole-5.5.2 qtpy-2.4.1 widgetsnbextension-4.0.11
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %% [raw]
# Pandas Seriler
# Pandas kütüphanesinin temel yapı birimleridir.
# Tek boyutlu bir veri yapısıdır.
# index: her eleman için benzersiz index nummarası id,
# veri türü: aynı seride tüm elemanlar tek bir veri türündedir,
# boyut: tek boyutlu satır veya sütun olabilir,
# işlemler: aritmetik, mantıksal ve matematiksel işlemler.

# %%
#Seri oluşturma
isimler=pd.Series(["Ali","Veli","Ayse"])
isimler
# Out:
# 0     Ali
# 1    Veli
# 2    Ayse
# dtype: object

# %%
type(isimler)
# Out:
# pandas.core.series.Series

# %%
isimler[0]
# Out:
# 'Ali'

# %%
isimler[0:2] #ilk iki isim indexleri 0 ve 1 olan
# Out:
# 0     Ali
# 1    Veli
# dtype: object

# %%
isimler[isimler.str.startswith("A")] #A ile başlayan isimler
# Out:
# 0     Ali
# 2    Ayse
# dtype: object

# %%
isimler[0] = 'Ahmet'
isimler
# Out:
# 0    Ahmet
# 1     Veli
# 2     Ayse
# dtype: object

# %%
puanlar=pd.Series([60,70,80,90])
puanlar
# Out:
# 0    60
# 1    70
# 2    80
# 3    90
# dtype: int64

# %%
puanlar.mean() #ortalama
# Out:
# 75.0

# %%
puanlar.std() #standart sapma
# Out:
# 12.909944487358056

# %%
uretim_miktarlari=pd.Series([100,200,300,400],index=["p1","p2","p3","p4"])
uretim_miktarlari
# Out:
# p1    100
# p2    200
# p3    300
# p4    400
# dtype: int64

# %%
uretim_miktarlari.sum() #toplam
# Out:
# 1000

# %%
#Tarih saat kütüphanesi
import datetime
tarihler=pd.date_range("2024-01-01",periods=10,freq="D")
uretim_miktarlari=pd.Series([100,200,300,400,700,1000,1600,2500,3200,4000],index=tarihler)
uretim_miktarlari
# Out:
# 2024-01-01     100
# 2024-01-02     200
# 2024-01-03     300
# 2024-01-04     400
# 2024-01-05     700
# 2024-01-06    1000
# 2024-01-07    1600
# 2024-01-08    2500
# 2024-01-09    3200
# 2024-01-10    4000
# Freq: D, dtype: int64

# %% [markdown]
# ## Örnek Veri Analizi

# %% [markdown]
# ## Kütüphaneleri Yükle veya İçe Aktar

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt #veri görselleştirme kütüphanesi
import seaborn as sns #daha görsel bir veri görselleştirme

# %% [markdown]
# ### Veri Dosyası Yükleme

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is BA88-10BB
#
#  Directory of C:\Users\aykut\OneDrive\Masa�st�\Techist\ders4
#
# 06.06.2024  20:12    <DIR>          .
# 06.06.2024  20:12    <DIR>          ..
# 06.06.2024  00:13    <DIR>          .ipynb_checkpoints
# 06.06.2024  00:01           109.988 1-1024x526.png
# 06.06.2024  20:06            38.001 ders4_pandas_kutuphanesi.ipynb
# 06.06.2024  00:11            67.870 pandas.png
# 06.06.2024  00:01            61.194 Titanic-Dataset.csv
#                4 File(s)        277.053 bytes
#                3 Dir(s)  140.830.564.352 bytes free

# %%
df=pd.read_csv("Titanic-Dataset.csv")

# %% [markdown]
# ## 3. Keşifsel Veri Analizi

# %%
#ilk 5 satıra bakmak
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# SibSp (Sibling Spouse): gemide bulunan kardeş (sibling) ve eş (spouse) sayısını temsil eder. Yani bu değer,yolcunun gemideki aile bağlarını gösterir.
# Parch (Parent Chiild): yolcunun Titanik gemisinde ki yolculuğu sırasında gemide bulunan ebeveyn (parent) ve çocuk (child) sayısını temsil eder.
# Fare: Bilet ücreti
# Embarked: Yolcunun bindiği liman

# %% [markdown]
# ### tail()

# %%
df.tail() #son 5 satırı listeler
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# ### info()

# %%
info
satır sayısı
sütun sayısı
veri türü dtypes: float64(2), int64(5), object(5)
eksik olmayan veri sayısını getirir.

# %%
df.info() #data frame hakkında bilgi verir
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### describe()
# Veri setinin betimsel istatistiklerini veriyor

# %%
df.describe(include="all")
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
#                Age       SibSp       Parch  Ticket        Fare    Cabin  \
# count   714.000000  891.000000  891.000000     891  891.000000      204
# unique         NaN         NaN         NaN     681         NaN      147
# top            NaN         NaN         NaN  347082         NaN  B96 B98
# freq           NaN         NaN         NaN       7         NaN        4
# mean     29.699118    0.523008    0.381594     NaN   32.204208      NaN
# std      14.526497    1.102743    0.806057     NaN   49.693429      NaN
# min       0.420000    0.000000    0.000000     NaN    0.000000      NaN
# 25%      20.125000    0.000000    0.000000     NaN    7.910400      NaN
# 50%      28.000000    0.000000    0.000000     NaN   14.454200      NaN
# 75%      38.000000    1.000000    0.000000     NaN   31.000000      NaN
# max      80.000000    8.000000    6.000000     NaN  512.329200      NaN
#
#        Embarked
# count       889
# unique        3
# top           S
# freq        644
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %% [markdown]
# Sayısal sütunlar için
# mean: Ortalama
# std : Standart sapma
# min : Minimum değer
# %25 : veriyi sıraladığımızda veri sayısının %25 ine geldğimizde ki değer
# %50 : veriyi sıraladığımızda veri sayısının %50 ine geldğimizde ki değer
# %75 :veriyi sıraladığımızda veri sayısının %75 ine geldğimizde ki değer
# max : Maksimum değer
# count : Veri sayısı

# %%
Kategorik Değerler
unique : kategori etiket adları
top    : en çok tekrar eden değer
freq   : kategoride ki sıklık

# %% [markdown]
# ### Aritmetiksel İşlemler

# %%
# basit bir şekilde sütunu seçmek
df["Name"] # yalnızca isim sütunu seçme
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df[['Name', 'Age']] # bşrden fazla seçmek
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
type(df[['Name', 'Age']]) # birden fazla sütun dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
df['Age'].max() #maksimum yaşı bul
# Out:
# 80.0

# %%
# filtreleme işlemi
df[df["Age"] == 80]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 630  male  80.0      0      0  27042  30.0   A23        S

# %%
df[df["Age"] == df['Age'].max()]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 630  male  80.0      0      0  27042  30.0   A23        S

# %%
df['Age'].mean() #yaş ortalamasını bulduk
# Out:
# 29.69911764705882

# %%
df['Age'].min() #min yaş
# Out:
# 0.42

# %%
df[df['Age'] == df['Age'].min()] #bebeğin kim olduğunu bulma en küçük yaş
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander  male
#
#       Age  SibSp  Parch Ticket    Fare Cabin Embarked
# 803  0.42      0      1   2625  8.5167   NaN        C

# %%
df['Age'].std() # standart sapma
# Out:
# 14.526497332334042

# %%
# yaşı 50'den küçüklerin listesi
df[df['Age']<50]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 885      5            382652  29.1250   NaN        Q
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [640 rows x 12 columns]

# %%
# yaşı 50'den küçük hayatta olan erkeklerin listesi (değişken atamalı)
df_50alti_surv_male_list=df[(df['Age']<50) & (df['Sex'] == 'male') & (df['Survived'] == 1)]
df_50alti_surv_male_list
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 21            22         1       2            Beesley, Mr. Lawrence  male
# 23            24         1       1     Sloper, Mr. William Thompson  male
# 74            75         1       3                    Bing, Mr. Lee  male
# 78            79         1       2    Caldwell, Master. Alden Gates  male
# 81            82         1       3      Sheerlinck, Mr. Jan Baptist  male
# ..           ...       ...     ...                              ...   ...
# 827          828         1       2            Mallet, Master. Andre  male
# 831          832         1       2  Richards, Master. George Sibley  male
# 838          839         1       3                  Chip, Mr. Chang  male
# 869          870         1       3  Johnson, Master. Harold Theodor  male
# 889          890         1       1            Behr, Mr. Karl Howell  male
#
#        Age  SibSp  Parch           Ticket     Fare Cabin Embarked
# 21   34.00      0      0           248698  13.0000   D56        S
# 23   28.00      0      0           113788  35.5000    A6        S
# 74   32.00      0      0             1601  56.4958   NaN        S
# 78    0.83      0      2           248738  29.0000   NaN        S
# 81   29.00      0      0           345779   9.5000   NaN        S
# ..     ...    ...    ...              ...      ...   ...      ...
# 827   1.00      0      2  S.C./PARIS 2079  37.0042   NaN        C
# 831   0.83      1      1            29106  18.7500   NaN        S
# 838  32.00      0      0             1601  56.4958   NaN        S
# 869   4.00      1      1           347742  11.1333   NaN        S
# 889  26.00      0      0           111369  30.0000  C148        C
#
# [86 rows x 12 columns]

# %% [markdown]
# #### Kategorik İşlemler

# %%
df['Sex'].value_counts() # kadın ve erkek sayısı
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df['Sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
df['Sex'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df.Sex.isnull().sum() # eksik veri sayısının toplamı
# Out:
# 0

# %%
df.Sex.isnull() #koşulu sağlama durumu yazıyor
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Sex, Length: 891, dtype: bool

# %%
df['Embarked'].unique() #kategori etiketlerini verir
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df['Embarked'].nunique() #kaç farklı kategori oldğunu verir.
# Out:
# 3

# %%
df['Age'].hist(bins=20)
# Out:
# <Axes: >

# %%
Southampton, İngiltere (Kalkış)
Cherbourg, Fransa
Queenstown (Cobh), İrlanda
New York City, ABD (Planlanan Varış)

# %%
# iloc kulanımı index location slicing dilimleme
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.iloc[0] # ilk satır
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
df.iloc[0:5] #ilk 5 satır
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.iloc[0:5,0:5] # ilk 5 satır ilk 5 sütunu başlangıç sayısını alır bitiş sayısnıı dahil etmez
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#loc kullanımı kolonların isimlerini kullanıyoruz
df.loc[0:5,['Name','Sex']] #belirtilen satırları ve belirtilen sütunları getirir adını ve cinsiyetini yazdı
# Out:
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
# 5                                   Moran, Mr. James    male

# %%
df.loc[0:5,'Name':'Fare'] # loc da belirtilen isimler
# Out:
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare
# 0      0         A/5 21171   7.2500
# 1      0          PC 17599  71.2833
# 2      0  STON/O2. 3101282   7.9250
# 3      0            113803  53.1000
# 4      0            373450   8.0500
# 5      0            330877   8.4583

# %%
#groupby
#Cinsiyete göre hayatta kalanların sayısı
df['Survived'].groupby(df['Sex']).value_counts()#sayı olarak
# Out:
# Sex     Survived
# female  1           233
#         0            81
# male    0           468
#         1           109
# Name: count, dtype: int64

# %%
df['Survived'].groupby(df['Sex']).value_counts(normalize=True)#oran olarak
# Out:
# Sex     Survived
# female  1           0.742038
#         0           0.257962
# male    0           0.811092
#         1           0.188908
# Name: proportion, dtype: float64

# %%
df['Survived'].groupby(df['Sex']).value_counts(normalize=True).plot.bar()
# Out:
# <Axes: xlabel='Sex,Survived'>

# %%
# ara görselleştirme
sns.countplot(x='Survived',hue='Sex',data=df) #countplot surived sayıalrını alır hue=hangi kategori
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
# Yolculuk sınıflarına göre hayatta kalma oranları
df['Survived'].groupby(df['Pclass']).value_counts(normalize=True)#oran olarak
# Out:
# Pclass  Survived
# 1       1           0.629630
#         0           0.370370
# 2       0           0.527174
#         1           0.472826
# 3       0           0.757637
#         1           0.242363
# Name: proportion, dtype: float64

# %%
sns.countplot(x='Survived',hue='Pclass',data=df); #countplot surived sayıalrını alır hue=hangi kategori

# %%
#Yolculuk sınıfında cinsiyete göre hayatta kalma
df['Survived'].groupby([df['Pclass'],df['Sex']]).value_counts(normalize=True)#oran olarak
# Out:
# Pclass  Sex     Survived
# 1       female  1           0.968085
#                 0           0.031915
#         male    0           0.631148
#                 1           0.368852
# 2       female  1           0.921053
#                 0           0.078947
#         male    0           0.842593
#                 1           0.157407
# 3       female  0           0.500000
#                 1           0.500000
#         male    0           0.864553
#                 1           0.135447
# Name: proportion, dtype: float64

# %%
df['Survived'].groupby([df['Pclass'],df['Sex']]).value_counts()#oran olarak
# Out:
# Pclass  Sex     Survived
# 1       female  1            91
#                 0             3
#         male    0            77
#                 1            45
# 2       female  1            70
#                 0             6
#         male    0            91
#                 1            17
# 3       female  0            72
#                 1            72
#         male    0           300
#                 1            47
# Name: count, dtype: int64

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df.groupby(['Pclass', 'Sex'])['Survived'].value_counts(normalize=True)# ikinci yöntem
# Out:
# Pclass  Sex     Survived
# 1       female  1           0.968085
#                 0           0.031915
#         male    0           0.631148
#                 1           0.368852
# 2       female  1           0.921053
#                 0           0.078947
#         male    0           0.842593
#                 1           0.157407
# 3       female  0           0.500000
#                 1           0.500000
#         male    0           0.864553
#                 1           0.135447
# Name: proportion, dtype: float64

# %%
# 3. sınıfda yolculuk eden kadınların hayatta kalma oranları
df[(df['Pclass']==3) & (df['Sex']=='female')]['Survived'].value_counts(normalize=True)
# Out:
# Survived
# 1    0.5
# 0    0.5
# Name: proportion, dtype: float64

# %%
#Örnek veri görselleştirme
plt.figure(figsize=(8,8))
sns.histplot(data=df,
             x='Age',hue='Survived',
            multiple='stack',
            kde=True,palette='pastel', bins=10, alpha=.5)
plt.title('Yaşa Göre Hayatta Kalma Dağılımı')
# Out:
# Text(0.5, 1.0, 'Yaşa Göre Hayatta Kalma Dağılımı')

# %%
df.describe(include='all') #number ve object
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
#                Age       SibSp       Parch  Ticket        Fare    Cabin  \
# count   714.000000  891.000000  891.000000     891  891.000000      204
# unique         NaN         NaN         NaN     681         NaN      147
# top            NaN         NaN         NaN  347082         NaN  B96 B98
# freq           NaN         NaN         NaN       7         NaN        4
# mean     29.699118    0.523008    0.381594     NaN   32.204208      NaN
# std      14.526497    1.102743    0.806057     NaN   49.693429      NaN
# min       0.420000    0.000000    0.000000     NaN    0.000000      NaN
# 25%      20.125000    0.000000    0.000000     NaN    7.910400      NaN
# 50%      28.000000    0.000000    0.000000     NaN   14.454200      NaN
# 75%      38.000000    1.000000    0.000000     NaN   31.000000      NaN
# max      80.000000    8.000000    6.000000     NaN  512.329200      NaN
#
#        Embarked
# count       889
# unique        3
# top           S
# freq        644
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %%
df.describe(include='number')
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe(include='object')
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
# betimsel istatistikleri topluca almak için
df.agg({
    'Age': ['min', 'max', 'median', 'skew'],
    'Fare': ['min', 'max', 'median', 'sum']   
})
# Out:
#               Age        Fare
# min      0.420000      0.0000
# max     80.000000    512.3292
# median  28.000000     14.4542
# skew     0.389108         NaN
# sum           NaN  28693.9493

# %%
#kadın ve erkek istatistikleri
df[['Sex','Age']].groupby('Sex').describe()
# Out:
#           Age
#         count       mean        std   min   25%   50%   75%   max
# Sex
# female  261.0  27.915709  14.110146  0.75  18.0  27.0  37.0  63.0
# male    453.0  30.726645  14.678201  0.42  21.0  29.0  39.0  80.0

# %%
df[['Sex','Age']].groupby('Sex').mean()
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645

# %%
#Geminin kaptanını bul
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df[df['Name'].str.contains('Capt')] #Titanic kaptanı değil
#Fare=71
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 745          746         0       1  Crosby, Capt. Edward Gifford  male  70.0
#
#      SibSp  Parch     Ticket  Fare Cabin Embarked
# 745      1      1  WE/P 5735  71.0   B22        S

# %%
df[df['Name'].str.contains('Crosby')] # bu kaptan Titanic kaptanı değil first class yolculuk yapan biri
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 540          541         1       1       Crosby, Miss. Harriet R  female
# 745          746         0       1  Crosby, Capt. Edward Gifford    male
#
#       Age  SibSp  Parch     Ticket  Fare Cabin Embarked
# 540  36.0      0      2  WE/P 5735  71.0   B22        S
# 745  70.0      1      1  WE/P 5735  71.0   B22        S

# %%
df[df['Cabin']=='B22']
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 540          541         1       1       Crosby, Miss. Harriet R  female
# 745          746         0       1  Crosby, Capt. Edward Gifford    male
#
#       Age  SibSp  Parch     Ticket  Fare Cabin Embarked
# 540  36.0      0      2  WE/P 5735  71.0   B22        S
# 745  70.0      1      1  WE/P 5735  71.0   B22        S

# %%
df[df['Name'].str.contains('Smith')]#Kaptanı arıyoruz
# Out:
#      PassengerId  Survived  Pclass                        Name     Sex   Age  \
# 174          175         0       1     Smith, Mr. James Clinch    male  56.0
# 260          261         0       3           Smith, Mr. Thomas    male   NaN
# 284          285         0       1  Smith, Mr. Richard William    male   NaN
# 346          347         1       2   Smith, Miss. Marion Elsie  female  40.0
#
#      SibSp  Parch  Ticket     Fare Cabin Embarked
# 174      0      0   17764  30.6958    A7        C
# 260      0      0  384461   7.7500   NaN        Q
# 284      0      0  113056  26.0000   A19        S
# 346      0      0   31418  13.0000   NaN        S

# %%
#ücret alınmayanlar
df[df['Fare']==0]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# 732          733         0       2              Knight, Mr. Robert J  male
# 806          807         0       1            Andrews, Mr. Thomas Jr  male
# 815          816         0       1                  Fry, Mr. Richard  male
# 822          823         0       1   Reuchlin, Jonkheer. John George  male
#
#       Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 179  36.0      0      0    LINE   0.0   NaN        S
# 263  40.0      0      0  112059   0.0   B94        S
# 271  25.0      0      0    LINE   0.0   NaN        S
# 277   NaN      0      0  239853   0.0   NaN        S
# 302  19.0      0      0    LINE   0.0   NaN        S
# 413   NaN      0      0  239853   0.0   NaN        S
# 466   NaN      0      0  239853   0.0   NaN        S
# 481   NaN      0      0  239854   0.0   NaN        S
# 597  49.0      0      0    LINE   0.0   NaN        S
# 633   NaN      0      0  112052   0.0   NaN        S
# 674   NaN      0      0  239856   0.0   NaN        S
# 732   NaN      0      0  239855   0.0   NaN        S
# 806  39.0      0      0  112050   0.0   A36        S
# 815   NaN      0      0  112058   0.0  B102        S
# 822  38.0      0      0   19972   0.0   NaN        S

# %%
df.sort_values(by='Age', ascending=False).head(10) #en yaşlı 10 kişi listesi
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 33            34         0       2                 Wheadon, Mr. Edward H
# 54            55         0       1        Ostby, Mr. Engelhart Cornelius
# 280          281         0       3                      Duane, Mr. Frank
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 630  male  80.0      0      0       27042  30.0000   A23        S
# 851  male  74.0      0      0      347060   7.7750   NaN        S
# 493  male  71.0      0      0    PC 17609  49.5042   NaN        C
# 96   male  71.0      0      0    PC 17754  34.6542    A5        C
# 116  male  70.5      0      0      370369   7.7500   NaN        Q
# 672  male  70.0      0      0  C.A. 24580  10.5000   NaN        S
# 745  male  70.0      1      1   WE/P 5735  71.0000   B22        S
# 33   male  66.0      0      0  C.A. 24579  10.5000   NaN        S
# 54   male  65.0      0      1      113509  61.9792   B30        C
# 280  male  65.0      0      0      336439   7.7500   NaN        Q

# %%
df.sort_values(by='Fare', ascending=False).head(10) #en pahalı bilet alan 10 kişi
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 258          259         1       1                       Ward, Miss. Anna
# 737          738         1       1                 Lesurer, Mr. Gustave J
# 679          680         1       1     Cardeza, Mr. Thomas Drake Martinez
# 88            89         1       1             Fortune, Miss. Mabel Helen
# 27            28         0       1         Fortune, Mr. Charles Alexander
# 341          342         1       1         Fortune, Miss. Alice Elizabeth
# 438          439         0       1                      Fortune, Mr. Mark
# 311          312         1       1             Ryerson, Miss. Emily Borie
# 742          743         1       1  Ryerson, Miss. Susan Parker "Suzette"
# 118          119         0       1               Baxter, Mr. Quigg Edmond
#
#         Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292              NaN        C
# 737    male  35.0      0      0  PC 17755  512.3292             B101        C
# 679    male  36.0      0      1  PC 17755  512.3292      B51 B53 B55        C
# 88   female  23.0      3      2     19950  263.0000      C23 C25 C27        S
# 27     male  19.0      3      2     19950  263.0000      C23 C25 C27        S
# 341  female  24.0      3      2     19950  263.0000      C23 C25 C27        S
# 438    male  64.0      1      4     19950  263.0000      C23 C25 C27        S
# 311  female  18.0      2      2  PC 17608  262.3750  B57 B59 B63 B66        C
# 742  female  21.0      2      2  PC 17608  262.3750  B57 B59 B63 B66        C
# 118    male  24.0      0      1  PC 17558  247.5208          B58 B60        C

# %%
#soyisimlerini ayıralım
df['Name'].str.split(',')
# Out:
# 0                             [Braund,  Mr. Owen Harris]
# 1      [Cumings,  Mrs. John Bradley (Florence Briggs ...
# 2                              [Heikkinen,  Miss. Laina]
# 3        [Futrelle,  Mrs. Jacques Heath (Lily May Peel)]
# 4                            [Allen,  Mr. William Henry]
#                              ...
# 886                             [Montvila,  Rev. Juozas]
# 887                      [Graham,  Miss. Margaret Edith]
# 888          [Johnston,  Miss. Catherine Helen "Carrie"]
# 889                             [Behr,  Mr. Karl Howell]
# 890                               [Dooley,  Mr. Patrick]
# Name: Name, Length: 891, dtype: object

# %%
df['Surname']=df['Name'].str.split(',').str.get(0) #soyisim isim arasında virgül olduğu için virgülden bölerek liste g-haline getirdik
#ve listedeki ilk eleman yani (soyisim) aldık
df['Surname']
# Out:
# 0         Braund
# 1        Cumings
# 2      Heikkinen
# 3       Futrelle
# 4          Allen
#          ...
# 886     Montvila
# 887       Graham
# 888     Johnston
# 889         Behr
# 890       Dooley
# Name: Surname, Length: 891, dtype: object

# %%
df['Name']=df['Name'].str.split(',').str.get(1) # listedeki ikinci elemanı yani ismi aldık
df['Name']
# Out:
# 0                                  Mr. Owen Harris
# 1       Mrs. John Bradley (Florence Briggs Thayer)
# 2                                      Miss. Laina
# 3               Mrs. Jacques Heath (Lily May Peel)
# 4                                Mr. William Henry
#                           ...
# 886                                    Rev. Juozas
# 887                           Miss. Margaret Edith
# 888                 Miss. Catherine Helen "Carrie"
# 889                                Mr. Karl Howell
# 890                                    Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df[df['Name'].str.contains('Countess')] # Konrtesleri bul
# Out:
#      PassengerId  Survived  Pclass  \
# 759          760         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 759   the Countess. of (Lucy Noel Martha Dyer-Edwards)  female  33.0      0
#
#      Parch  Ticket  Fare Cabin Embarked Surname
# 759      0  110152  86.5   B77        S  Rothes

# %%
df['Name'].str.len().idxmax() # en uzun ismin indexini verir
# Out:
# 307

# %%
df.iloc[307,3] #en uzun ismi buldum
# Out:
# ' Mrs. Victor de Satode (Maria Josefa Perez de Soto y Vallejo)'

# %%
df['Sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
#KAtegorileri değiştirebiliriz
df['Sex'].replace({'male':1,
                  'female':0},inplace=True) # değişikliği dataframe üzerine uygular
# Out:
# C:\Users\aykut\AppData\Local\Temp\ipykernel_17792\2881453571.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Sex'].replace({'male':1,

# %%
# ikinci yöntem replace(['male','female'],['M','F'])

# %%
df['Sex']
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    0
# 889    1
# 890    1
# Name: Sex, Length: 891, dtype: int64

# %%
#data framede veri türünü değişirme şu an çalışmaz
df['Age']=df['Age'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[95], line 2
#       1 #data framede veri türünü değişirme şu an çalışmaz
# ----> 2 df['Age']=df['Age'].astype('int')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\dtypes\astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\dtypes\astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\dtypes\astype.py:101, in _astype_nansafe(arr, dtype, copy, skipna)
#      96     return lib.ensure_string_array(
#      97         arr, skipna=skipna, convert_na_value=False
#      98     ).reshape(shape)
#     100 elif np.issubdtype(arr.dtype, np.floating) and dtype.kind in "iu":
# --> 101     return _astype_float_to_int_nansafe(arr, dtype, copy)
#     103 elif arr.dtype == object:
#     104     # if we have a datetime/timedelta array of objects
#     105     # then coerce to datetime64[ns] and use DatetimeArray.astype
#     107     if lib.is_np_dtype(dtype, "M"):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\dtypes\astype.py:145, in _astype_float_to_int_nansafe(values, dtype, copy)
#     141 """
#     142 astype with a check preventing converting NaN to an meaningless integer value.
#     143 """
#     144 if not np.isfinite(values).all():
# --> 145     raise IntCastingNaNError(
#     146         "Cannot convert non-finite values (NA or inf) to integer"
#     147     )
#     148 if dtype.kind == "u":
#     149     # GH#45151
#     150     if not (values >= 0).all():
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer
